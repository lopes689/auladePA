# %% [markdown]
# <a href="https://colab.research.google.com/github/lopes689/auladePA/blob/main/aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula de programação e Algoritmos

# %%
print("hello world")
# Out:
# hello world

# %%
a = 5
b = 6
t = a + b

# %%
#Tipos Numéricos
idade = 14 # int
altura = 1.75 # float
numero_complexo = 2 + 3j # complex

#tipo texto
nome = "Emanuel"  # str

#tipo booleano
esta_chovendo = False # bool

#tipo lista (mutável)
numeros = {1,2,3,4,5} # list

#tipo tupla (imutável)
coordenadas = (10,20) # tuple

#tipo conjunto (valores unicos)
vogais = {'a','e','i','o','u'} # set

#Tipo dicionário (chave-valor)
pessoa = {"nome": "Emanuel", "idade": 14 } # dict
# Out:
#   File "/tmp/ipython-input-332/2679114903.py", line 22
#     pessoa = {"nome"; "Emanuel", "idade": 14 } # dict
#                     ^
# SyntaxError: invalid syntax
