# %% [markdown]
# <a href="https://colab.research.google.com/github/lopes689/auladePA/blob/main/atividade_avaliativa_(Emanuel_Lopes_Moreira).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.Par ou ímpar

#Peça um número ao usuário e informe se ele é par ou ímpar.

numero = int(input("digite um numero: "))
num = numero % 2
if num == 0:
  print(f"o numero {6} é par")
else:
  print(f" o numero {7} é impar")
# Out:
# digite um numero: 6
# o numero 6 é par

# %%
#2.Maior de dois números

#Solicite dois números e mostre qual é o maior (ou se são iguais).

# entrada

a = int(input("digite um numero: "))
b = int(input("digite outro numero: "))

#processamento e saida

if a > b:
  print(f"{7} é maior que {6}")
elif a == b:
  print(f"{7} é igual a {7}")
else:
  print(f"{8} é maior que {6}")
# Out:
# digite um numero: 7
# digite outro numero: 7
# 7 é igual a 7

# %%
#3.Aprovação de aluno

#Peça a nota de um aluno e informe:

#Aprovado (nota ≥ 7)

#Recuperação (5 ≤ nota < 7)

#Reprovado (nota < 5)

nome = str(input("qual seu nome? "))
n1 = float(input(" qual sua nota do Primeiro bimestre? "))
if n1 > 10:
  print(" digite uma nota valida  (de 0 a 10)")
n2 = float(input(" qual sua nota do Segundo bimestre? "))
if n2 > 10:
  print(" digite uma nota valida  (de 0 a 10)")
n3 = float(input(" qual sua nota do Terceiro bimestre? "))
if n3 > 10:
  print(" digite uma nota valida  (de 0 a 10)")
n4 = float(input(" qual sua nota do Quarto bimestre? "))
if n4 > 10:
  print(" digite uma nota valida  (de 0 a 10)")
nf = n1 + n2 + n3 + n4
nb = nf / 4
if n1 > 10 or n2 > 10 or n3 > 10 or n4 > 10:
  print("digite notas validas (0 a 10)")
elif nb >= 7:
  print(f"o aluno {nome}  tirou {nb}  e foi aprovado")
elif nb >= 5:
    print(f"o aluno {nome} tirou {nb} e ficou de recuperação")
else:
    print(f"o aluno {nome} tirou {nb} foi reprovado")
# Out:
# qual seu nome? Emanuel Lopes Moreira
#  qual sua nota do Primeiro bimestre? 9
#  qual sua nota do Segundo bimestre? 7
#  qual sua nota do Terceiro bimestre? 6
#  qual sua nota do Quarto bimestre? 7
# o aluno Emanuel Lopes Moreira  tirou 7.25  e foi aprovado

# %%
#4.Classificação de idade
#Receba a idade e classifique:
#Criança (0–12)
#Adolescente (13–17)
#Adulto (18–59)
#Idoso (60+)
idade = int(input("digite sua idade"))
if idade <= 12:
  print("você é uma criança")
elif idade >= 13 and idade <= 17:
  print("você é um adolecente")
elif idade >= 18 and idade <= 59:
  print("você é um adulto")
else:
  print("você é um idoso")
# Out:
# digite sua idade14
# você é um adolecente

# %%
#5.Senha correta
#Defina uma senha fixa no código. Peça ao usuário para digitar e informe se está correta ou incorreta.

senh = int (input("qual sua senha? "))
senha = 123
if senh == senha:
  print(" acesso permitido")
else:
  print("acesso negado")
# Out:
# qual sua senha? 123
#  acesso permitido

# %%
#6.Positivo, negativo ou zero

#Peça um número e diga se ele é positivo, negativo ou zero.

nu = float(input("digite um numero"))
if nu > 0:
  print(f"o numero {9} é positivo")
elif nu == 0:
    print(f"o numero {0} é igual a zero")
else:
    print(f"o numero {-2} é negativo")
# Out:
# digite um numero-2
# o numero -2 é negativo

# %%
#7.Calculadora simples

#Peça dois números e uma operação (+, -, *, /). Use if/elif para calcular o resultado.

a = int(input("digite um numero: "))
b = int(input("digite um numero: "))
q = str(input("qual função voce quer usar? (use somente mult,soma,sub e div) "))
if q == "soma":
  print(a + b)
elif q == "sub":
  print(a - b)
elif q == "mult":
  print(a * b)
elif q == "div":
  print(a / b)
# Out:
# digite um numero: 7
# digite um numero: 6
# qual função voce quer usar? (use somente mult,soma,sub e div) mult
# 42

# %%
#8.Dia da semana

#Peça um número de 1 a 7 e mostre o dia correspondente (ex: 1 = domingo).

nume = int(input("digite um numero entre 1 e 7"))
if nume > 7:
  print("digite um numero valido")
elif nume == 1:
  print(f"o numero {1} equivale ao dia da semana: domingo")
elif nume == 2:
  print(f"o numero {2} equivale ao dia da semana: segunda-feira")
elif nume == 3:
  print(f"o numero {3} equivale ao dia da semana: terça-feira")
elif nume == 4:
  print(f"o numero {4} equivale ao dia da semana: quarta-feira")
elif nume == 5:
  print(f"o numero {5} equivale ao dia da semana: quinta-feira")
elif nume == 6:
  print(f"o numero {6} equivale ao dia da semana: sexta-feira")
else:
  print(f"o numero {7} equivale ao dia da semana: sabado")
# Out:
# digite um numero entre 1 e 76
# o numero 6 equivale ao dia da semana: sexta-feira

# %%
#9.Ano bissexto

#Solicite um ano e informe se ele é bissexto ou não.

#se for divisível por 4, exceto para anos múltiplos de 100 que não são múltiplos de 400

ano = int(input("digite um ano"))
if ano % 4 == 0:
  print(f"o ano {366} é bissexto")


else:
   print(f"o ano {365} não é bissexto")
# Out:
# digite um ano365
# o ano 365 não é bissexto

# %%
#10.

#Desconto em compras

#Peça o valor de uma compra:

#≥ 100: 10% de desconto

#≥ 50 e < 100: 5% de desconto

#< 50: sem desconto

valor = float(input("qual o valor de sua compra? "))
if valor >= 100:
  desc = valor * 0.1
  prec = valor - desc
  print(f"sua compra ganhou 10% de desconto e ficou {prec}")
elif valor >= 50 and valor < 100:
  desc = valor * 0.05
  prec = valor - desc
  print(f"sua compra ganhou 5% de desconto e ficou {prec}")
else:
  print(f"sua compra não ganhou desconto, e ficou {valor}")
# Out:
# qual o valor de sua compra? 75
# sua compra ganhou 5% de desconto e ficou 71.25
